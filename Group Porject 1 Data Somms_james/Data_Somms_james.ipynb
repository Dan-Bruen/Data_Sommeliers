# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress
import requests
import json

#ignore normal warnings
import warnings; warnings.simplefilter('ignore')

import gmaps

# Google developer API key
from config import gkey

# Access maps with unique API key
gmaps.configure(api_key=gkey)

# %%
# Storing our Data World Wine filepath in a variable
data_world_wines = "../Group Porject 1 Data Somms/DataWorldWines.csv"

# %% [markdown]
# ## Explore price with reference to different variable - find the max, min, mean - James
# <br> By grape
# <br> By vintage
# <br>By region
# <br> By vintage + region

# %%
# Preview the Data World Wine dataframe
data_world_wines_df = pd.read_csv(data_world_wines, encoding="ISO-8859-1")
data_world_wines_df.head()
# Out:
#     Vintage   Country                           County         Designation  \
# 0  1/1/1919     Spain                             Cava  1919 Brut Selecci¢
# 1  1/1/1929     Italy       Vernaccia di San Gimignano                 NaN
# 2  1/1/1929     Italy  Sangiovese di Romagna Superiore            Prugneto
# 3  1/1/1934  Portugal                              NaN       Reserva Velho
# 4  1/1/1945    France                       Rivesaltes      Legend Vintage
#
#    Points    Price              Province  \
# 0      88   $13.00             Catalonia
# 1      87   $14.00               Tuscany
# 2      84   $15.00         Central Italy
# 3      93  $495.00               Colares
# 4      95  $350.00  Languedoc-Roussillon
#
#                                                Title          Variety  \
# 0     L'Arboc NV 1919 Brut Selecci¢ Sparkling (Cava)  Sparkling Blend
# 1         Guidi 1929 2015 Vernaccia di San Gimignano        Vernaccia
# 2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...       Sangiovese
# 3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...          Ramisco
# 4  Grard Bertrand 1945 Legend Vintage Red (Rives...        Red Blend
#
#                     Winery
# 0                  L'Arboc
# 1               Guidi 1929
# 2  Poderi dal Nespoli 1929
# 3        Adega Viuva Gomes
# 4          Grard Bertrand

# %%
#create new column with price as float
data_world_wines_df['Price_Float'] = data_world_wines_df['Price'].replace('[\$,]', '', regex=True).astype(float)
data_world_wines_df.head()
# Out:
#     Vintage   Country                           County         Designation  \
# 0  1/1/1919     Spain                             Cava  1919 Brut Selecci¢
# 1  1/1/1929     Italy       Vernaccia di San Gimignano                 NaN
# 2  1/1/1929     Italy  Sangiovese di Romagna Superiore            Prugneto
# 3  1/1/1934  Portugal                              NaN       Reserva Velho
# 4  1/1/1945    France                       Rivesaltes      Legend Vintage
#
#    Points    Price              Province  \
# 0      88   $13.00             Catalonia
# 1      87   $14.00               Tuscany
# 2      84   $15.00         Central Italy
# 3      93  $495.00               Colares
# 4      95  $350.00  Languedoc-Roussillon
#
#                                                Title          Variety  \
# 0     L'Arboc NV 1919 Brut Selecci¢ Sparkling (Cava)  Sparkling Blend
# 1         Guidi 1929 2015 Vernaccia di San Gimignano        Vernaccia
# 2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...       Sangiovese
# 3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...          Ramisco
# 4  Grard Bertrand 1945 Legend Vintage Red (Rives...        Red Blend
#
#                     Winery  Price_Float
# 0                  L'Arboc         13.0
# 1               Guidi 1929         14.0
# 2  Poderi dal Nespoli 1929         15.0
# 3        Adega Viuva Gomes        495.0
# 4          Grard Bertrand        350.0

# %%
data_world_wines_df['Country'].describe()
# Out:
# count     24989
# unique       37
# top          US
# freq      10576
# Name: Country, dtype: object

# %%
data_world_wines_df['Price_Float'].describe()
# Out:
# count    23375.00000
# mean        35.46708
# std         40.83522
# min          4.00000
# 25%         17.00000
# 50%         25.00000
# 75%         42.00000
# max       2500.00000
# Name: Price_Float, dtype: float64

# %%
#find top 5 the most expensive wine
data_world_wines_df.sort_values(by='Price_Float',ascending=False).head(10)
# Out:
#         Vintage    Country                County  \
# 20970  1/1/2014     France               Pomerol
# 10344  1/1/2010     France         Saint-milion
# 7158   1/1/2009  Australia           Eden Valley
# 22902  1/1/2015    Germany                   NaN
# 15968  1/1/2012      Spain               Priorat
# 737    1/1/2003    Hungary                   NaN
# 21755  1/1/2014     France  Chevalier-Montrachet
# 20172  1/1/2014     France  Chevalier-Montrachet
# 9682   1/1/2010    Germany                   NaN
# 10962  1/1/2011     France              Pauillac
#
#                                     Designation  Points      Price  \
# 20970                                       NaN      96  $2,500.00
# 10344                                       NaN     100  $1,500.00
# 7158                              Hill of Grace      91    $780.00
# 22902  Kiedrich Grfenberg Trockenbeerenauslese      98    $775.00
# 15968                                  El Perer      96    $770.00
# 737                                    Essencia      94    $764.00
# 21755                                       NaN      95    $710.00
# 20172                                       NaN      95    $685.00
# 9682   Kiedrich Grfenberg Trockenbeerenauslese      96    $672.00
# 10962                                       NaN      97    $660.00
#
#               Province                                              Title  \
# 20970         Bordeaux                        Chteau Ptrus 2014 Pomerol
# 10344         Bordeaux            Chteau Cheval Blanc 2010 Saint-milion
# 7158   South Australia   Henschke 2009 Hill of Grace Shiraz (Eden Valley)
# 22902         Rheingau  Robert Weil 2015 Kiedrich Grfenberg Trockenbe...
# 15968        Catalonia      Marco Abella 2012 El Perer Carignan (Priorat)
# 737             Tokaji                Royal Tokaji 2003 Essencia (Tokaji)
# 21755         Burgundy         Olivier Leflaive 2014 Chevalier-Montrachet
# 20172         Burgundy   Domaine Jacques Prieur 2014 Chevalier-Montrachet
# 9682          Rheingau  Robert Weil 2010 Kiedrich Grfenberg Trockenbe...
# 10962         Bordeaux                       Chteau Latour 2011 Pauillac
#
#                         Variety                  Winery  Price_Float
# 20970  Bordeaux-style Red Blend          Chteau Ptrus       2500.0
# 10344  Bordeaux-style Red Blend    Chteau Cheval Blanc       1500.0
# 7158                     Shiraz                Henschke        780.0
# 22902                  Riesling             Robert Weil        775.0
# 15968                  Carignan            Marco Abella        770.0
# 737                     Furmint            Royal Tokaji        764.0
# 21755                Chardonnay        Olivier Leflaive        710.0
# 20172                Chardonnay  Domaine Jacques Prieur        685.0
# 9682                   Riesling             Robert Weil        672.0
# 10962  Bordeaux-style Red Blend          Chteau Latour        660.0

# %%
data_world_wines_df['Price_Per_Points'] = data_world_wines_df['Price_Float'] / data_world_wines_df['Points']
data_world_wines_df[data_world_wines_df['Price_Float'] > 17].sort_values(by='Price_Per_Points').head(10)
# Out:
#         Vintage   Country                County            Designation  \
# 21853  1/1/2014   Austria                   NaN           Ried Steiger
# 6045   1/1/2009        US             Mendocino              Cuvee 128
# 6269   1/1/2009        US      Sierra Foothills  Monarch Mine Vineyard
# 24370  1/1/2016   Austria                   NaN                  Stein
# 18021  1/1/2013        US           Napa Valley                Lot 457
# 13749  1/1/2012  Portugal                   NaN                Reserva
# 22314  1/1/2015    Canada      Beamsville Bench                 Estate
# 12207  1/1/2011  Portugal                   NaN                  Tinto
# 21984  1/1/2014    France        Pessac-Lognan                    NaN
# 15494  1/1/2012        US  Columbia Valley (WA)                    NaN
#
#        Points   Price    Province  \
# 21853      93  $18.00      Wachau
# 6045       93  $18.00  California
# 6269       93  $18.00  California
# 24370      93  $18.00     Kamptal
# 18021      93  $18.00  California
# 13749      93  $18.00       Douro
# 22314      93  $18.00     Ontario
# 12207      93  $18.00      Lisboa
# 21984      92  $18.00    Bordeaux
# 15494      92  $18.00  Washington
#
#                                                    Title  \
# 21853        Fischer 2014 Ried Steiger Riesling (Wachau)
# 6045   Navarro 2009 Cuvee 128 Sauvignon Blanc (Mendoc...
# 6269   Easton 2009 Monarch Mine Vineyard Sauvignon Bl...
# 24370  Jurtschitsch 2016 Stein Grner Veltliner (Kamp...
# 18021  Cameron Hughes 2013 Lot 457 Meritage (Napa Val...
# 13749            Quinta da Rede 2012 Reserva Red (Douro)
# 22314  Cave Spring 2015 Estate Riesling (Beamsville B...
# 12207       Quinta de Chocapalha 2011 Tinto Red (Lisboa)
# 21984                Chteau Couhins 2014 Pessac-Lognan
# 15494  Woodinville Wine Cellars 2012 Sauvignon Blanc ...
#
#                         Variety                    Winery  Price_Float  \
# 21853                  Riesling                   Fischer         18.0
# 6045            Sauvignon Blanc                   Navarro         18.0
# 6269            Sauvignon Blanc                    Easton         18.0
# 24370          Grner Veltliner              Jurtschitsch         18.0
# 18021                  Meritage            Cameron Hughes         18.0
# 13749            Portuguese Red            Quinta da Rede         18.0
# 22314                  Riesling               Cave Spring         18.0
# 12207            Portuguese Red      Quinta de Chocapalha         18.0
# 21984  Bordeaux-style Red Blend           Chteau Couhins         18.0
# 15494           Sauvignon Blanc  Woodinville Wine Cellars         18.0
#
#        Price_Per_Points
# 21853          0.193548
# 6045           0.193548
# 6269           0.193548
# 24370          0.193548
# 18021          0.193548
# 13749          0.193548
# 22314          0.193548
# 12207          0.193548
# 21984          0.195652
# 15494          0.195652

# %%
#find the most expensive wine
data_world_wines_df['Price_Float'].nlargest(3)
# Out:
# 20970    2500.0
# 10344    1500.0
# 7158      780.0
# Name: Price_Float, dtype: float64

# %%
data_world_wines_df.boxplot('Price_Float',by="Points")

# %%
# Extract individual groups
# group1 = df[df["treatment"] == 1]["mosq"]
# group2 = df[df["treatment"] == 2]["mosq"]
# group3 = df[df["treatment"] == 3]["mosq"]
# group4 = df[df["treatment"] == 4]["mosq"]
# group5 = df[df["treatment"] == 5]["mosq"]

# %%
# stats.f_oneway(group1, group2, group3, group4, group5)

# %%
data_world_wines_df_grouped_grape = data_world_wines_df.groupby(['Variety'])
data_world_wines_df_grouped_grape.count()
# Out:
#                         Vintage  Country  County  Designation  Points  Price  \
# Variety
# Agiorgitiko                   8        8       0            3       8      8
# Aglianico                    72       72      72           49      72     58
# Albana                        9        9       8            8       9      8
# Albari¤o                     93       93      91           49      93     93
# Aleatico                      1        1       1            1       1      1
# ...                         ...      ...     ...          ...     ...    ...
# Zierfandler-Rotgipfler        3        3       0            0       3      3
# Zinfandel                   517      517     516          385     517    516
# Zlahtina                      1        1       0            0       1      1
# Zweigelt                     48       48       2           36      48     40
# «ilavka                      1        1       0            0       1      1
#
#                         Province  Title  Winery  Price_Float  Price_Per_Points
# Variety
# Agiorgitiko                    8      8       8            8                 8
# Aglianico                     72     72      72           58                58
# Albana                         9      9       9            8                 8
# Albari¤o                      93     93      93           93                93
# Aleatico                       1      1       1            1                 1
# ...                          ...    ...     ...          ...               ...
# Zierfandler-Rotgipfler         3      3       3            3                 3
# Zinfandel                    517    517     517          516               516
# Zlahtina                       1      1       1            1                 1
# Zweigelt                      48     48      48           40                40
# «ilavka                       1      1       1            1                 1
#
# [450 rows x 11 columns]

# %%
data_world_wines_df_grouped_grape.mean()['Price_Float'].nlargest(20)
# Out:
# Variety
# Ramisco                      495.000000
# Furmint                      149.000000
# Champagne Blend              101.571429
# Malbec Blend                  95.000000
# Mazuelo                       92.000000
# Vitovska                      85.000000
# Pinot Noir-Syrah              80.000000
# Shiraz-Cabernet               75.000000
# Carignan                      69.105263
# Syrah-Cabernet Franc          69.000000
# Nebbiolo                      66.777283
# Sangiovese Grosso             64.653846
# Port                          64.333333
# Malbec-Cabernet Sauvignon     62.307692
# Moscatel                      60.666667
# Shiraz-Viognier               60.375000
# Babi?                        60.000000
# Tinta Francisca               60.000000
# Chardonnay-Pinot Blanc        59.000000
# Tokaji                        58.833333
# Name: Price_Float, dtype: float64

# %%
plt.plot(data_world_wines_df_grouped_grape.mean())
# Out:
# [<matplotlib.lines.Line2D at 0x19a2a592388>,
#  <matplotlib.lines.Line2D at 0x19a2a5dd1c8>,
#  <matplotlib.lines.Line2D at 0x19a2a5dd388>]

# %%
data_world_wines_df_grouped_country = data_world_wines_df.groupby(['Country'])
data_world_wines_df_grouped_country.count()
# Out:
#                 Vintage  County  Designation  Points  Price  Province  Title  \
# Country
# Argentina           760     750          582     760    749       760    760
# Australia           465     465          318     465    460       465    465
# Austria             692       0          591     692    569       692    692
# Brazil                9       0            9       9      7         9      9
# Bulgaria             31       0           21      31     31        31     31
# Canada               52      52           34      52     52        52     52
# Chile               924       0          789     924    919       924    924
# Croatia              15       0            9      15     15        15     15
# Czech Republic        1       0            0       1      1         1      1
# England               7       0            7       7      6         7      7
# France             4058    4048         2607    4058   3286      4058   4058
# Georgia              20       0           13      20     19        20     20
# Germany             419       0          398     419    414       419    419
# Greece               74       0           50      74     73        74     74
# Hungary              29       0           24      29     29        29     29
# India                 1       0            1       1      1         1      1
# Israel              113       0           94     113    109       113    113
# Italy              3704    3701         2569    3704   3228      3704   3704
# Lebanon               5       0            3       5      5         5      5
# Luxembourg            2       0            2       2      2         2      2
# Macedonia             4       0            2       4      4         4      4
# Mexico               18       0           13      18     18        18     18
# Moldova              11       0           10      11     11        11     11
# Morocco               4       0            3       4      4         4      4
# New Zealand         273       0          140     273    263       273    273
# Peru                  2       0            2       2      2         2      2
# Portugal           1108       0          993    1108    973      1108   1108
# Romania              28       0           26      28     28        28     28
# Serbia                3       0            2       3      3         3      3
# Slovenia             14       0            9      14     12        14     14
# South Africa        267       0          154     267    252       267    267
# Spain              1255    1252          990    1255   1239      1255   1255
# Switzerland           1       0            0       1      1         1      1
# Turkey               16       0           10      16     16        16     16
# US                10576   10541         7132   10576  10538     10576  10576
# Ukraine               3       0            1       3      3         3      3
# Uruguay              25       0           21      25     25        25     25
#
#                 Variety  Winery  Price_Float  Price_Per_Points
# Country
# Argentina           760     760          749               749
# Australia           465     465          460               460
# Austria             692     692          569               569
# Brazil                9       9            7                 7
# Bulgaria             31      31           31                31
# Canada               52      52           52                52
# Chile               924     924          919               919
# Croatia              15      15           15                15
# Czech Republic        1       1            1                 1
# England               7       7            6                 6
# France             4058    4058         3286              3286
# Georgia              20      20           19                19
# Germany             419     419          414               414
# Greece               74      74           73                73
# Hungary              29      29           29                29
# India                 1       1            1                 1
# Israel              113     113          109               109
# Italy              3704    3704         3228              3228
# Lebanon               5       5            5                 5
# Luxembourg            2       2            2                 2
# Macedonia             4       4            4                 4
# Mexico               18      18           18                18
# Moldova              11      11           11                11
# Morocco               4       4            4                 4
# New Zealand         273     273          263               263
# Peru                  2       2            2                 2
# Portugal           1108    1108          973               973
# Romania              28      28           28                28
# Serbia                3       3            3                 3
# Slovenia             14      14           12                12
# South Africa        267     267          252               252
# Spain              1255    1255         1239              1239
# Switzerland           1       1            1                 1
# Turkey               16      16           16                16
# US                10576   10576        10538             10538
# Ukraine               3       3            3                 3
# Uruguay              25      25           25                25

# %%
data_world_wines_df_grouped_country.count()['Price_Float'].nlargest(12)
# Out:
# Country
# US              10538
# France           3286
# Italy            3228
# Spain            1239
# Portugal          973
# Chile             919
# Argentina         749
# Austria           569
# Australia         460
# Germany           414
# New Zealand       263
# South Africa      252
# Name: Price_Float, dtype: int64

# %%
top12_countries = data_world_wines_df_grouped_country.count()['Price_Float'].nlargest(12)

# %%
plt.plot(data_world_wines_df_grouped_country['Price_Float'].mean())
plt.xticks(rotation='vertical')
plt.grid(True)

plt.title('Average Price By Country')
plt.ylabel('Price ($USD)')
plt.xlabel('Country')
# Out:
# Text(0.5, 0, 'Country')

# %%
data_world_wines_df_grouped_points = data_world_wines_df.groupby(['Points'])
data_world_wines_df_grouped_points.mean()
# Out:
#         Price_Float  Price_Per_Points
# Points
# 80        15.463768          0.193297
# 81        16.734848          0.206603
# 82        18.876623          0.230203
# 83        18.733333          0.225703
# 84        19.732980          0.234916
# 85        20.634684          0.242761
# 86        22.046721          0.256357
# 87        24.089380          0.276889
# 88        28.308500          0.321688
# 89        32.152458          0.361264
# 90        37.212025          0.413467
# 91        43.253542          0.475314
# 92        49.842201          0.541763
# 93        63.388389          0.681596
# 94        78.901274          0.839375
# 95       112.597902          1.185241
# 96       185.510638          1.932402
# 97       185.142857          1.908689
# 98       165.437500          1.688138
# 99       260.000000          2.626263
# 100      555.000000          5.550000

# %%
(555-14.46)/20
# Out:
# 27.026999999999997

# %%
data_world_wines_df['Price_Float'].mean()/data_world_wines_df['Points'].mean()
# Out:
# 0.40081929896656615

# %%
data_world_wines_df_grouped_points.count()
# Out:
#         Vintage  Country  County  Designation  Price  Province  Title  \
# Points
# 80           69       69      57           38     69        69     69
# 81          133      133     108           85    132       133    133
# 82          317      317     262          188    308       317    317
# 83          588      588     486          348    570       588    588
# 84         1191     1191     979          706   1131      1191   1191
# 85         1798     1798    1463         1104   1678      1798   1798
# 86         2480     2477    2031         1567   2333      2477   2480
# 87         3247     3245    2716         2152   3032      3245   3247
# 88         3256     3255    2753         2197   3047      3255   3256
# 89         2362     2361    1920         1720   2217      2361   2362
# 90         3027     3026    2492         2249   2844      3026   3027
# 91         2192     2192    1848         1719   2047      2192   2192
# 92         1808     1808    1515         1459   1654      1808   1808
# 93         1360     1360    1160         1125   1223      1360   1360
# 94          672      672     582          570    628       672    672
# 95          311      311     265          258    286       311    311
# 96           99       99      89           84     94        99     99
# 97           60       60      57           44     56        60     60
# 98           16       16      15           11     16        16     16
# 99            7        7       7            7      6         7      7
# 100           4        4       4            2      4         4      4
#
#         Variety  Winery  Price_Float  Price_Per_Points
# Points
# 80           69      69           69                69
# 81          133     133          132               132
# 82          317     317          308               308
# 83          588     588          570               570
# 84         1191    1191         1131              1131
# 85         1798    1798         1678              1678
# 86         2480    2480         2333              2333
# 87         3247    3247         3032              3032
# 88         3256    3256         3047              3047
# 89         2362    2362         2217              2217
# 90         3027    3027         2844              2844
# 91         2192    2192         2047              2047
# 92         1808    1808         1654              1654
# 93         1360    1360         1223              1223
# 94          672     672          628               628
# 95          311     311          286               286
# 96           99      99           94                94
# 97           60      60           56                56
# 98           16      16           16                16
# 99            7       7            6                 6
# 100           4       4            4                 4

# %%
x_axis = np.arange(80,101,1)
plt.plot(data_world_wines_df_grouped_points.mean())
plt.xticks(rotation='vertical')
plt.grid(True)

plt.title('Average Price By Points')
plt.ylabel('Price ($USD)')
plt.xlabel('Points (Out of 100)')
plt.xticks(x_axis)
# Out:
# ([<matplotlib.axis.XTick at 0x19a2acd4a48>,
#   <matplotlib.axis.XTick at 0x19a2ad10f88>,
#   <matplotlib.axis.XTick at 0x19a2b0da5c8>,
#   <matplotlib.axis.XTick at 0x19a2b0fa3c8>,
#   <matplotlib.axis.XTick at 0x19a2b0fa4c8>,
#   <matplotlib.axis.XTick at 0x19a2b0fe488>,
#   <matplotlib.axis.XTick at 0x19a2b102148>,
#   <matplotlib.axis.XTick at 0x19a2b102948>,
#   <matplotlib.axis.XTick at 0x19a2b106088>,
#   <matplotlib.axis.XTick at 0x19a2b106ac8>,
#   <matplotlib.axis.XTick at 0x19a2b10b548>,
#   <matplotlib.axis.XTick at 0x19a2ab11fc8>,
#   <matplotlib.axis.XTick at 0x19a2b10fd08>,
#   <matplotlib.axis.XTick at 0x19a2b10b4c8>,
#   <matplotlib.axis.XTick at 0x19a2b102888>,
#   <matplotlib.axis.XTick at 0x19a2b114d88>,
#   <matplotlib.axis.XTick at 0x19a2b117788>,
#   <matplotlib.axis.XTick at 0x19a2b11a088>,
#   <matplotlib.axis.XTick at 0x19a2b11ab48>,
#   <matplotlib.axis.XTick at 0x19a2b11e6c8>,
#   <matplotlib.axis.XTick at 0x19a2b122388>],
#  <a list of 21 Text xticklabel objects>)

# %%
# plt.bar(data_world_wines_df_grouped_points.count()['Vintage'])

# %%
# Set line
(slope, intercept, r_value, p_value, std_err) = linregress(x_axis, data_world_wines_df_grouped_points.mean()['Price_Float'])
fit = slope * x_axis + intercept

# %%
# Plot data
fig, ax = plt.subplots()

fig.suptitle("Wine Data Test", fontsize=16, fontweight="bold")

# ax.set_xlim(0, 10)
# ax.set_ylim(0, 10)

ax.set_xlabel('Points (Out of 100)')
ax.set_ylabel('Price ($USD)')
plt.xticks(x_axis)
plt.grid(True)

ax.plot(x_axis, data_world_wines_df_grouped_points.mean()['Price_Float'], linewidth=0, marker='o')
#'b--' blue line with dashes
ax.plot(x_axis, fit, 'r--')

plt.show()

# Loop through the countries for each

# %%
slope
# Out:
# 15.293594971140783

# %%
r_value *r_value
# Out:
# 0.5564581510285337

# %% [markdown]
# # Steps Analysis Starts Here:

# %%
#Regression analysis on data points from all countries
# Set line
x_axis = np.arange(80,101,1)
(slope, intercept, r_value, p_value, std_err) = linregress(x_axis, data_world_wines_df_grouped_points.mean()['Price_Float'])
fit = slope * x_axis + intercept

# %%
# Plot data
fig, ax = plt.subplots()

fig.suptitle("Wine - Price Per Point Increase", fontsize=16, fontweight="bold")

ax.set_xlabel('Points (Out of 100)')
ax.set_ylabel('Price ($USD)')
plt.xticks(x_axis)
plt.grid(True)

ax.plot(x_axis, data_world_wines_df_grouped_points.mean()['Price_Float'], linewidth=0, marker='o')
#'b--' blue line with dashes
ax.plot(x_axis, fit, 'r--')

plt.show()

# %%
#group df by country then points
data_world_wines_df_grouped_country_points = data_world_wines_df.groupby(['Country','Points']).mean()
data_world_wines_df_grouped_country_points.loc['France'].head()
# Out:
#         Price_Float  Price_Per_Points
# Points
# 80        10.000000          0.125000
# 81        15.333333          0.189300
# 82        14.666667          0.178862
# 83        16.230769          0.195551
# 84        17.795031          0.211846

# %%
data_world_wines_df_grouped_country_points.index.isin()
# Out:
#                   Price_Float  Price_Per_Points
# Country   Points
# Argentina 80        14.071429          0.175893
#           81        12.863636          0.158810
#           82        14.120000          0.172195
#           83        14.706897          0.177192
#           84        15.082192          0.179550
# ...                       ...               ...
# Uruguay   86        21.333333          0.248062
#           87        18.000000          0.206897
#           88        44.400000          0.504545
#           89        32.666667          0.367041
#           92        43.000000          0.467391
#
# [352 rows x 2 columns]

# %%
data_world_wines_df_grouped_country_points.index.isin((top6_countries_names))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-07df2cc17ffe> in <module>
# ----> 1 data_world_wines_df_grouped_country_points.index.isin((top6_countries_names))
#
# D:\anaconda\lib\site-packages\pandas\core\indexes\multi.py in isin(self, values, level)
#    3424     def isin(self, values, level=None):
#    3425         if level is None:
# -> 3426             values = MultiIndex.from_tuples(values, names=self.names).values
#    3427             return algos.isin(self.values, values)
#    3428         else:
#
# D:\anaconda\lib\site-packages\pandas\core\indexes\multi.py in from_tuples(cls, tuples, sortorder, names)
#     481                 tuples = tuples._values
#     482
# --> 483             arrays = list(lib.tuples_to_object_array(tuples).T)
#     484         elif isinstance(tuples, list):
#     485             arrays = list(lib.to_object_array_tuples(tuples).T)
#
# pandas\_libs\lib.pyx in pandas._libs.lib.tuples_to_object_array()
#
# TypeError: Expected tuple, got str

# %%
x_axis = np.arange(80,101,1)
for c in co
plt.plot(data_world_wines_df_grouped_country_points)
plt.xticks(rotation='vertical')
plt.grid(True)

plt.title('Average Price By Points')
plt.ylabel('Price ($USD)')
plt.xlabel('Points (Out of 100)')
plt.xticks(x_axis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-e99742b134e1> in <module>
#       1 x_axis = np.arange(80,101,1)
# ----> 2 plt.plot(data_world_wines_df_grouped_country_points)
#       3 plt.xticks(rotation='vertical')
#       4 plt.grid(True)
#       5
#
# D:\anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# D:\anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# D:\anaconda\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# D:\anaconda\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# D:\anaconda\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     241     def _xy_from_xy(self, x, y):
#     242         if self.axes.xaxis is not None and self.axes.yaxis is not None:
# --> 243             bx = self.axes.xaxis.update_units(x)
#     244             by = self.axes.yaxis.update_units(y)
#     245
#
# D:\anaconda\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1491         neednew = self.converter != converter
#    1492         self.converter = converter
# -> 1493         default = self.converter.default_units(data, self)
#    1494         if default is not None and self.units is None:
#    1495             self.set_units(default)
#
# D:\anaconda\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     113         # default_units->axis_info->convert
#     114         if axis.units is None:
# --> 115             axis.set_units(UnitData(data))
#     116         else:
#     117             axis.units.update(data)
#
# D:\anaconda\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     179         self._counter = itertools.count()
#     180         if data is not None:
# --> 181             self.update(data)
#     182
#     183     @staticmethod
#
# D:\anaconda\lib\site-packages\matplotlib\category.py in update(self, data)
#     216             # OrderedDict just iterates over unique values in data.
#     217             if not isinstance(val, (str, bytes)):
# --> 218                 raise TypeError("{val!r} is not a string".format(val=val))
#     219             if convertible:
#     220                 # this will only be called so long as convertible is True.
#
# TypeError: ('Argentina', 80) is not a string

# %%
data_world_wines_df_grouped_country_points.loc['France']['Price_Float'].fillna(0)
# Out:
# Points
# 80      10.000000
# 81      15.333333
# 82      14.666667
# 83      16.230769
# 84      17.795031
# 85      18.919847
# 86      19.660550
# 87      21.415190
# 88      25.726872
# 89      29.525424
# 90      34.232295
# 91      43.604651
# 92      53.718487
# 93      75.125000
# 94      97.035714
# 95     200.767857
# 96     335.000000
# 97     292.375000
# 98     274.666667
# 99       0.000000
# 100    875.000000
# Name: Price_Float, dtype: float64

# %%
#loop through top 6 countries to produce combined chart
x_axis = np.arange(80,101,1)
avg_wine_price = data_world_wines_df_grouped_points.mean()['Price_Float']
top6_countries = data_world_wines_df_grouped_country.count()['Price_Float'].nlargest(6)
top6_countries_names = top6_countries.index
top6_countries_names
# Out:
# Index(['US', 'France', 'Italy', 'Spain', 'Portugal', 'Chile'], dtype='object', name='Country')

# %%
data_world_wines_df_grouped_country.mean().index
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Brazil', 'Bulgaria', 'Canada',
#        'Chile', 'Croatia', 'Czech Republic', 'England', 'France', 'Georgia',
#        'Germany', 'Greece', 'Hungary', 'India', 'Israel', 'Italy', 'Lebanon',
#        'Luxembourg', 'Macedonia', 'Mexico', 'Moldova', 'Morocco',
#        'New Zealand', 'Peru', 'Portugal', 'Romania', 'Serbia', 'Slovenia',
#        'South Africa', 'Spain', 'Switzerland', 'Turkey', 'US', 'Ukraine',
#        'Uruguay'],
#       dtype='object', name='Country')

# %%
countries = data_world_wines_df_grouped_country.mean().index

# %%
lats =[]
lngs =[]

for country in countries:
    params = {"address": country, "key": gkey}

    # Build URL using the Google Maps API
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    # Run request
    response = requests.get(base_url, params=params)

    # Convert to JSON
    country_geo = response.json()

    # Extract lat/lng
    lats.append(country_geo["results"][0]["geometry"]["location"]["lat"])
    lngs.append(country_geo["results"][0]["geometry"]["location"]["lng"])
    print(country)
    print (country_geo["results"][0]["geometry"]["location"]["lat"])
    print (country_geo["results"][0]["geometry"]["location"]["lng"])

    # Print results
# Out:
# Argentina
# -38.416097
# -63.61667199999999
# Australia
# -25.274398
# 133.775136
# Austria
# 47.516231
# 14.550072
# Brazil
# -14.235004
# -51.92528
# Bulgaria
# 42.733883
# 25.48583
# Canada
# 56.130366
# -106.346771
# Chile
# -35.675147
# -71.542969
# Croatia
# 45.1
# 15.2000001
# Czech Republic
# 49.81749199999999
# 15.472962
# England
# 52.3555177
# -1.1743197
# France
# 46.227638
# 2.213749
# Georgia
# 32.1656221
# -82.9000751
# Germany
# 51.165691
# 10.451526
# Greece
# 39.074208
# 21.824312
# Hungary
# 47.162494
# 19.5033041
# India
# 20.593684
# 78.96288
# Israel
# 31.046051
# 34.851612
# Italy
# 41.87194
# 12.56738
# Lebanon
# 33.854721
# 35.862285
# Luxembourg
# 49.815273
# 6.129582999999999
# Macedonia
# 41.608635
# 21.745275
# Mexico
# 23.634501
# -102.552784
# Moldova
# 47.411631
# 28.369885
# Morocco
# 31.791702
# -7.092619999999999
# New Zealand
# -40.900557
# 174.885971
# Peru
# -9.189967
# -75.015152
# Portugal
# 39.39987199999999
# -8.224454
# Romania
# 45.943161
# 24.96676
# Serbia
# 44.016521
# 21.005859
# Slovenia
# 46.151241
# 14.995463
# South Africa
# -30.559482
# 22.937506
# Spain
# 40.46366700000001
# -3.74922
# Switzerland
# 46.818188
# 8.227511999999999
# Turkey
# 38.963745
# 35.243322
# US
# 37.09024
# -95.712891
# Ukraine
# 48.379433
# 31.1655799
# Uruguay
# -32.522779
# -55.765835
# [-38.416097,
#  -25.274398,
#  47.516231,
#  -14.235004,
#  42.733883,
#  56.130366,
#  -35.675147,
#  45.1,
#  49.81749199999999,
#  52.3555177,
#  46.227638,
#  32.1656221,
#  51.165691,
#  39.074208,
#  47.162494,
#  20.593684,
#  31.046051,
#  41.87194,
#  33.854721,
#  49.815273,
#  41.608635,
#  23.634501,
#  47.411631,
#  31.791702,
#  -40.900557,
#  -9.189967,
#  39.39987199999999,
#  45.943161,
#  44.016521,
#  46.151241,
#  -30.559482,
#  40.46366700000001,
#  46.818188,
#  38.963745,
#  37.09024,
#  48.379433,
#  -32.522779]

# %%
# data_world_wines_df_grouped_country.mean()['Lat'] = lats
# data_world_wines_df_grouped_country.mean()['Lng'] = lngs
data_world_wines_df_grouped_country_geocodes = data_world_wines_df_grouped_country.mean()
data_world_wines_df_grouped_country_geocodes['Lat'] = lats
data_world_wines_df_grouped_country_geocodes['Lng'] = lngs
data_world_wines_df_grouped_country_geocodes
# Out:
#                    Points  Price_Float  Price_Per_Points        Lat  \
# Country
# Argentina       86.767105    24.325768          0.275207 -38.416097
# Australia       88.660215    37.617391          0.416338 -25.274398
# Austria         90.197977    29.349736          0.322899  47.516231
# Brazil          83.888889    17.000000          0.203133 -14.235004
# Bulgaria        87.709677    15.612903          0.176716  42.733883
# Canada          89.480769    36.365385          0.404388  56.130366
# Chile           86.480519    20.394995          0.232455 -35.675147
# Croatia         87.933333    30.533333          0.344176  45.100000
# Czech Republic  85.000000    25.000000          0.294118  49.817492
# England         91.571429    43.333333          0.474426  52.355518
# France          88.890833    41.340231          0.454153  46.227638
# Georgia         87.700000    19.894737          0.227460  32.165622
# Germany         90.016706    45.917874          0.499826  51.165691
# Greece          87.837838    23.068493          0.262677  39.074208
# Hungary         88.827586    66.206897          0.729479  47.162494
# India           92.000000    19.000000          0.206522  20.593684
# Israel          88.575221    32.247706          0.362318  31.046051
# Italy           88.597192    39.318773          0.437680  41.871940
# Lebanon         87.400000    36.600000          0.418408  33.854721
# Luxembourg      89.000000    22.500000          0.252904  49.815273
# Macedonia       87.500000    16.250000          0.185525  41.608635
# Mexico          84.277778    28.055556          0.331293  23.634501
# Moldova         87.454545    16.545455          0.187333  47.411631
# Morocco         89.000000    19.750000          0.221923  31.791702
# New Zealand     88.358974    28.140684          0.315688 -40.900557
# Peru            85.500000    18.500000          0.216279  -9.189967
# Portugal        88.361011    24.620761          0.273516  39.399872
# Romania         86.000000    22.142857          0.258619  45.943161
# Serbia          88.000000    25.000000          0.282859  44.016521
# Slovenia        88.285714    24.166667          0.272787  46.151241
# South Africa    88.082397    25.948413          0.291833 -30.559482
# Spain           87.337849    28.307506          0.317450  40.463667
# Switzerland     89.000000   160.000000          1.797753  46.818188
# Turkey          88.062500    27.687500          0.315597  38.963745
# US              88.602591    36.917821          0.412378  37.090240
# Ukraine         84.000000     6.000000          0.071429  48.379433
# Uruguay         86.240000    25.160000          0.288730 -32.522779
#
#                        Lng
# Country
# Argentina       -63.616672
# Australia       133.775136
# Austria          14.550072
# Brazil          -51.925280
# Bulgaria         25.485830
# Canada         -106.346771
# Chile           -71.542969
# Croatia          15.200000
# Czech Republic   15.472962
# England          -1.174320
# France            2.213749
# Georgia         -82.900075
# Germany          10.451526
# Greece           21.824312
# Hungary          19.503304
# India            78.962880
# Israel           34.851612
# Italy            12.567380
# Lebanon          35.862285
# Luxembourg        6.129583
# Macedonia        21.745275
# Mexico         -102.552784
# Moldova          28.369885
# Morocco          -7.092620
# New Zealand     174.885971
# Peru            -75.015152
# Portugal         -8.224454
# Romania          24.966760
# Serbia           21.005859
# Slovenia         14.995463
# South Africa     22.937506
# Spain            -3.749220
# Switzerland       8.227512
# Turkey           35.243322
# US              -95.712891
# Ukraine          31.165580
# Uruguay         -55.765835

# %%
# Store latitude and longitude in locations
locations = data_world_wines_df_grouped_country_geocodes[["Lat", "Lng"]]

# Fill NaN values and convert to float
rating = data_world_wines_df_grouped_country_geocodes["Price_Per_Points"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
x_axis
# Out:
# array([ 80,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,  92,
#         93,  94,  95,  96,  97,  98,  99, 100])

# %%
data_world_wines_df_grouped_country_points.loc[country]['Price_Float'].fillna(0)
# Out:
# Points
# 81      32.000000
# 82      25.777778
# 83      16.222222
# 84      18.476744
# 85      20.906977
# 86      21.976945
# 87      24.694158
# 88      32.004016
# 89      40.616402
# 90      46.773632
# 91      52.356828
# 92      59.312849
# 93      68.259036
# 94      79.913978
# 95     107.468750
# 96     121.166667
# 97     120.200000
# 98      81.666667
# 99     517.500000
# 100    270.000000
# Name: Price_Float, dtype: float64

# %%
data_world_wines_df_grouped_country_points.loc['Chile'].index
# Out:
# Int64Index([80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94], dtype='int64', name='Points')

# %%
#Regression each country
(slope, intercept, r_value, p_value, std_err) = linregress(x_axis, data_world_wines_df_grouped_country_points.loc['US']['Price_Float'].fillna(0))
fit = slope * x_axis + intercept

(slope_fr, intercept_fr, r_value_fr, p_value_fr, std_err_fr) = linregress(x_axis, data_world_wines_df_grouped_country_points.loc['France']['Price_Float'].fillna(0))
fit_fr = slope_fr * x_axis + intercept_fr

(slope_chile, intercept_chile, r_value_chile, p_value_chile, std_err_chile) = linregress(data_world_wines_df_grouped_country_points.loc['Chile'].index, data_world_wines_df_grouped_country_points.loc['Chile']['Price_Float'].fillna(0))
fit_chile = slope_chile * x_axis + intercept_chile

(slope_germany, intercept_germany, r_value_germany, p_value_germany, std_err_germany) = linregress(data_world_wines_df_grouped_country_points.loc['Germany'].index, data_world_wines_df_grouped_country_points.loc['Germany']['Price_Float'].fillna(0))
fit_germany = slope_germany * x_axis + intercept_germany

# %%
fig, ax = plt.subplots()

fig.suptitle("Wine - Price Per Point Increase(US)", fontsize=16, fontweight="bold")

ax.set_xlabel('Points (Out of 100)')
ax.set_ylabel('Price ($USD)')
plt.xticks(x_axis)
plt.grid(True)

# ax.plot(x_axis, data_world_wines_df_grouped_points.mean()['Price_Float'], linewidth=0, marker='o')
#'b--' blue line with dashes
ax.plot(x_axis, fit, 'r--',label='US')
ax.plot(x_axis, fit_fr, 'b--')
ax.plot(x_axis, fit_chile, 'black')
ax.plot(x_axis, fit_germany, 'orange')
plt.legend()



plt.show()

# %%
#show second chart with labels

# %%
# anova
group1 = df[df["HairColour"] == "LightBlond"]["Pain"]
group2 = df[df["HairColour"] == "DarkBlond"]["Pain"]
group3 = df[df["HairColour"] == "LightBrunette"]["Pain"]
group4 = df[df["HairColour"] == "DarkBrunette"]["Pain"]

# %%
# Perform the ANOVA
stats.f_oneway(group1, group2, group3, group4)
